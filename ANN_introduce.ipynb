# %% [markdown]
# <a href="https://colab.research.google.com/github/viettran02/AI_project/blob/main/ANN_introduce.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.models import load_model
import matplotlib.pyplot as plt
from keras.utils import load_img, img_to_array
import numpy as np

model100 = load_model('/content/drive/MyDrive/cifar100.h5')

# %%
img = load_img('/content/drive/MyDrive/automobile1.png')
img = img_to_array(img)
img = img.reshape(1, 32*32*3)
img = img.astype('float32')
img = img/255
np.argmax(model100.predict(img), axis = -1)
plt.imshow(img)
plt.show()
# Out:
# 1/1 [==============================] - 0s 46ms/step

# %%
from matplotlib.image import imread
folder = '/content/drive/MyDrive/img20'
for i in range(5):
  plt.subplot(1,5,i+1)
  filename = folder +'/A'+ str(i) + '.jpg'
  img = imread(filename)
  plt.imshow(img)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
from google.colab import drive
drive.mount('/content/drive')
