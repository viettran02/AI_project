# %% [markdown]
# <a href="https://colab.research.google.com/gist/viettran02/885849ab5ef8694639e7c072b48952e4/ai_week2_ex.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from pandas.core.groupby.generic import DataFrame
import pandas as pd

url ='http://winterolympicsmedals.com/medals.csv'
data = pd.read_csv(url)
data.head(21)
# Out:
#     Year      City       Sport       Discipline  NOC                Event  \
# 0   1924  Chamonix     Skating   Figure skating  AUT           individual
# 1   1924  Chamonix     Skating   Figure skating  AUT           individual
# 2   1924  Chamonix     Skating   Figure skating  AUT                pairs
# 3   1924  Chamonix   Bobsleigh        Bobsleigh  BEL             four-man
# 4   1924  Chamonix  Ice Hockey       Ice Hockey  CAN           ice hockey
# 5   1924  Chamonix    Biathlon         Biathlon  FIN      military patrol
# 6   1924  Chamonix     Skating   Figure skating  FIN                pairs
# 7   1924  Chamonix     Skating    Speed skating  FIN               10000m
# 8   1924  Chamonix     Skating    Speed skating  FIN               10000m
# 9   1924  Chamonix     Skating    Speed skating  FIN                1500m
# 10  1924  Chamonix     Skating    Speed skating  FIN                5000m
# 11  1924  Chamonix     Skating    Speed skating  FIN                5000m
# ...

# %% [markdown]
# Dữ liệu tìm được từ trang web

# %%
data = data.set_index(data['NOC'])
data.loc['FIN']
# Out:
#      Year      City     Sport       Discipline  NOC                 Event  \
# NOC
# FIN  1924  Chamonix  Biathlon         Biathlon  FIN       military patrol
# FIN  1924  Chamonix   Skating   Figure skating  FIN                 pairs
# FIN  1924  Chamonix   Skating    Speed skating  FIN                10000m
# FIN  1924  Chamonix   Skating    Speed skating  FIN                10000m
# FIN  1924  Chamonix   Skating    Speed skating  FIN                 1500m
# ..    ...       ...       ...              ...  ...                   ...
# FIN  2006     Turin    Skiing   Freestyle Ski.  FIN                moguls
# FIN  2006     Turin    Skiing  Nordic Combined  FIN                  Team
# FIN  2006     Turin    Skiing      Ski Jumping  FIN       K120 team (90m)
# FIN  2006     Turin    Skiing      Ski Jumping  FIN  K90 individual (70m)
# FIN  2006     Turin    Skiing        Snowboard  FIN             Half-pipe
#
#     Event gender   Medal
# NOC
# FIN            M  Silver
# ...

# %% [markdown]
# Dữ liệu huy chương của 1 nước (FIN)

# %%
data.groupby(['Sport','Medal' == 'Gold']).count()
# Out:
#                    Year  City  Discipline  NOC  Event  Event gender
# Sport      Medal
# Biathlon   Bronze    54    54          54   54     54            54
#            Gold      54    54          54   54     54            54
#            Silver    54    54          54   54     54            54
# Bobsleigh  Bronze    45    45          45   45     45            45
#            Gold      45    45          45   45     45            45
#            Silver    43    43          43   43     43            43
# Curling    Bronze     7     7           7    7      7             7
#            Gold       7     7           7    7      7             7
#            Silver     7     7           7    7      7             7
# Ice Hockey Bronze    23    23          23   23     23            23
#            Gold      23    23          23   23     23            23
#            Silver    23    23          23   23     23            23
# Luge       Bronze    36    36          36   36     36            36
# ...

# %% [markdown]
# Số huy chương của một môn thể thao

# %%
data[(data['Sport'] == 'Skiing')&(data['Medal'] == 'Gold')]
# Out:
#      Year        City   Sport       Discipline  NOC                 Event  \
# NOC
# NOR  1924    Chamonix  Skiing  Cross Country S  NOR                  18km
# NOR  1924    Chamonix  Skiing  Cross Country S  NOR                  50km
# NOR  1924    Chamonix  Skiing  Nordic Combined  NOR            individual
# NOR  1924    Chamonix  Skiing      Ski Jumping  NOR  K90 individual (70m)
# NOR  1928  St. Moritz  Skiing  Cross Country S  NOR                  18km
# ..    ...         ...     ...              ...  ...                   ...
# USA  2006       Turin  Skiing    Alpine Skiing  USA       Alpine combined
# USA  2006       Turin  Skiing    Alpine Skiing  USA          giant slalom
# USA  2006       Turin  Skiing        Snowboard  USA             Half-pipe
# USA  2006       Turin  Skiing        Snowboard  USA             Half-pipe
# USA  2006       Turin  Skiing        Snowboard  USA       Snowboard Cross
#
#     Event gender Medal
# NOC
# NOR            M  Gold
# ...

# %% [markdown]
# Số HCV của môn skiing
